# %% [markdown]
# Implementation from https://github.com/nikhilbarhate99/PPO-PyTorch/blob/master/PPO_colab.ipynb

# %%
import os
import torch
import torch.nn as nn
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from cathedral_rl import cathedral_v0  
import random
import numpy as np

# %%
################################## set device ##################################

print("============================================================================================")


# set device to cpu or cuda
device = torch.device('cpu')

if(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    print("Device set to : cpu")
    
print("============================================================================================")
# Out:
# ============================================================================================
# Device set to : NVIDIA RTX A5000
# ============================================================================================

# %%
class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.state_values = []
        self.is_terminals = []
        self.action_masks = []
    
    def clear(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.state_values[:]
        del self.is_terminals[:]
        del self.action_masks[:]


class ActorCritic(nn.Module):
    def __init__(self, obs_shape, action_dim):
        super(ActorCritic, self).__init__()
        
        # Calculate input size from observation shape
        self.state_dim = obs_shape[0] * obs_shape[1] * obs_shape[2]  # Flattened input
        self.action_dim = action_dim

        # Actor network - outputs action probabilities
        self.actor = nn.Sequential(
            nn.Linear(self.state_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, action_dim)
            # No softmax here - will apply it with action mask later
        )
        
        # Critic network - outputs state value
        self.critic = nn.Sequential(
            nn.Linear(self.state_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 1)
        )
        
    def forward(self):
        raise NotImplementedError
    
    def act(self, state, action_mask):
        # Flatten state for linear layers
        state_flat = state.reshape(-1)
        
        # Get action logits from actor
        action_logits = self.actor(state_flat)
        
        # Apply action mask (set invalid actions to negative infinity)
        action_mask_tensor = torch.tensor(action_mask, dtype=torch.bool)
        action_logits[~action_mask_tensor] = -1e8
        
        # Apply softmax to get action probabilities
        action_probs = torch.softmax(action_logits, dim=0)
        
        # Create categorical distribution
        dist = Categorical(action_probs)
        
        # Sample action
        action = dist.sample()
        action_logprob = dist.log_prob(action)
        
        # Get state value from critic
        state_val = self.critic(state_flat)
        
        return action.detach(), action_logprob.detach(), state_val.detach()
    
    def evaluate(self, states, actions, action_masks):
        # Flatten states for linear layers
        batch_size = states.shape[0]
        states_flat = states.reshape(batch_size, -1)
        
        # Get action logits from actor for all states
        action_logits = self.actor(states_flat)
        
        # Apply action masks (set invalid actions to negative infinity)
        for i in range(batch_size):
            action_mask = action_masks[i]
            action_logits[i][~action_mask] = -1e8
        
        # Apply softmax to get action probabilities
        action_probs = torch.softmax(action_logits, dim=1)
        
        # Create categorical distributions
        dist = Categorical(action_probs)
        
        # Get log probabilities, entropies, and state values
        action_logprobs = dist.log_prob(actions)
        dist_entropy = dist.entropy()
        state_values = self.critic(states_flat)
        
        return action_logprobs, state_values, dist_entropy


class PPO:
    def __init__(self, obs_shape, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip):
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.buffer = RolloutBuffer()
        
        self.policy = ActorCritic(obs_shape, action_dim).to(device)
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])
        
        self.policy_old = ActorCritic(obs_shape, action_dim).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()
    
    def select_action(self, state, action_mask):
        with torch.no_grad():
            state_tensor = torch.FloatTensor(state).to(device)
            action_mask_tensor = torch.BoolTensor(action_mask).to(device)
            action, action_logprob, state_val = self.policy_old.act(state_tensor, action_mask_tensor)
        
        self.buffer.states.append(state_tensor)
        self.buffer.actions.append(action)
        self.buffer.logprobs.append(action_logprob)
        self.buffer.state_values.append(state_val)
        self.buffer.action_masks.append(action_mask_tensor)
        
        return action.item()
    
    def update(self):
        # Monte Carlo estimate of returns
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            #print(f'reward {reward}, is terminal {is_terminal}')
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards (if there are any)
        if len(rewards) > 0:
            rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
            #print(f' reward normalisation {rewards}')
            if rewards.std() > 0:
                rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)
        else:
            return  # Nothing to update if buffer is empty
        
        # Convert lists to tensors
        old_states = torch.stack(self.buffer.states).detach().to(device)
        old_actions = torch.stack(self.buffer.actions).detach().to(device)
        old_logprobs = torch.stack(self.buffer.logprobs).detach().to(device)
        old_state_values = torch.stack(self.buffer.state_values).detach().squeeze().to(device)
        old_action_masks = torch.stack(self.buffer.action_masks).detach().to(device)
        
        # Calculate advantages
        advantages = rewards - old_state_values
        #print(f'Advantages {advantages.mean()}, rewards {rewards.mean()} old state values {old_state_values.mean()}')
        
        # Optimize policy for K epochs
        for _ in range(self.K_epochs):
            # Evaluating old actions and values
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions, old_action_masks)
            
            # Match state_values tensor dimensions with rewards tensor
            state_values = torch.squeeze(state_values)
            
            # Finding the ratio (pi_theta / pi_theta__old)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            
            # Finding Surrogate Loss
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            mse_loss = self.MseLoss(state_values, rewards)
            #print(f' surr1 {surr1.mean()}, surr2{surr2.mean()} mse loss * 0.5 {mse_loss.mean() * 0.5} dist entropy * 0.01 {0.01 * dist_entropy.mean()}')
            
            # Final loss of clipped objective PPO
            loss = -torch.min(surr1, surr2) + 0.5 * mse_loss - 0.01 * dist_entropy
            
            # Take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        
        # Copy new weights into old policy
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        # Clear buffer
        self.buffer.clear()
    
    def save(self, checkpoint_path):
        torch.save(self.policy_old.state_dict(), checkpoint_path)
    
    def load(self, checkpoint_path):
        self.policy_old.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
        self.policy.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))

# %%
has_continuous_action_space = False

K_epochs = 40               # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
gamma = 0.95                # discount factor

lr_actor = 0.005       # learning rate for actor network
lr_critic = 0.002

# %%
board_size = 8
num_episodes = 2500
save_freq = 500
factor_illegal_action = 1

# %% [markdown]
# ### Pure self play of PPO vs itself

# %%
def train_ppo_self_play(name):
    env = cathedral_v0.env(board_size=board_size, render_mode="text", per_move_rewards=True, final_reward_score_difference=False)
    env.reset()
    
    # Get action space and observation shape (should be the same for both players)
    player_0 = "player_0"
    player_1 = "player_1"
    n_actions = env.action_space(player_0).n
    obs_shape = env.observe(player_0)["observation"].shape  # (10, 10, 5)
    
    print(f'n_actions: {n_actions}')
    print(f'observation shape: {obs_shape}')
    
    # Initialize PPO agent (will be used for both players)
    ppo_agent = PPO(
        obs_shape=obs_shape,
        action_dim=n_actions,
        lr_actor=lr_actor,
        lr_critic=lr_critic,
        gamma=gamma,
        K_epochs=K_epochs,
        eps_clip=eps_clip
    )
    
    # Training statistics
    list_reward_p0 = []
    list_reward_p1 = []
    policy_checkpoints = []
    list_win_count_p0 = []
    list_win_count_p1 = []
    list_draw_count = []
    
    # Training loop
    for episode in range(num_episodes):
        print(f'Episode {episode}')
        env.reset()
        print(f"Starting player: {env.agent_selection}")
        total_reward_p0 = 0
        total_reward_p1 = 0
        episode_timesteps = 0
        
        # Clear player buffer
        ppo_agent.buffer.clear()
        
        while env.agents:
            current_agent = env.agent_selection
            observation = env.observe(current_agent)
            state = observation["observation"]
            action_mask = observation["action_mask"]
            
            # Both players use PPO to select actions
            action = ppo_agent.select_action(state, action_mask)
            
            # Take action in environment
            env.step(action)
            
            # Get reward
            reward = env.rewards[current_agent]
            
            # Track total rewards
            if current_agent == player_0:
                total_reward_p0 += reward
            else:
                total_reward_p1 += reward
            
            # Store reward in appropriate buffer
            ppo_agent.buffer.rewards.append(reward)
            
            # Check if episode is done
            if current_agent not in env.agents:
                ppo_agent.buffer.is_terminals.append(1)
            else:
                ppo_agent.buffer.is_terminals.append(0)
            
            episode_timesteps += 1
        
        print(f'Timesteps of the episode {episode_timesteps}')
        
        # Update PPO policy using both players' experiences
        if episode >= 10:  # Start updating after collecting some experience
            # Combine experiences from both players
            ppo_agent.update()
        
        # Collect statistics
        print(f'Total rewards p0 {total_reward_p0} and p1 {total_reward_p1}')
        list_reward_p0.append(total_reward_p0)
        list_reward_p1.append(total_reward_p1)
        
        # Track wins for player_0 (for consistency with the old tracking)
        if not list_win_count_p0:
            list_win_count_p0 = [0]
        if not list_win_count_p1:  # You need this list too
            list_win_count_p1 = [0]
        if not list_draw_count:
            list_draw_count = [0]

        # Update the appropriate counter based on the game outcome
        if env.winner == 0:  # player_0 wins
            list_win_count_p0.append(list_win_count_p0[-1] + 1)
            list_win_count_p1.append(list_win_count_p1[-1])  # Carry forward p1 count unchanged
            list_draw_count.append(list_draw_count[-1])  # Carry forward draw count unchanged
            
        elif env.winner == 1:  # player_1 wins
            list_win_count_p0.append(list_win_count_p0[-1])  # Carry forward p0 count unchanged
            list_win_count_p1.append(list_win_count_p1[-1] + 1)
            list_draw_count.append(list_draw_count[-1])  # Carry forward draw count unchanged
            
        elif env.winner == -1:  # draw
            list_win_count_p0.append(list_win_count_p0[-1])  # Carry forward p0 count unchanged
            list_win_count_p1.append(list_win_count_p1[-1])  # Carry forward p1 count unchanged
            list_draw_count.append(list_draw_count[-1] + 1)
        
        if (episode + 1) % 100 == 0:
            win_rate_p0 = list_win_count_p0[-1] / (episode + 1)
            win_rate_p1 = list_win_count_p1[-1] / (episode + 1)
            draw_rate = list_draw_count[-1] / (episode + 1)
            
            print(f"Episode {episode+1}/{num_episodes}")
            print(f"  Player 0 - Avg Reward: {sum(list_reward_p0[-100:]) / 100:.2f} - Win Rate: {win_rate_p0}")
            print(f"  Player 1 - Avg Reward: {sum(list_reward_p1[-100:]) / 100:.2f} - Win Rate: {win_rate_p1}")
            print(f"  Draw Rate: {draw_rate:.2f}")
            
        # Save checkpoint
        if (episode+1) % save_freq == 0:
            policy_checkpoints.append(ppo_agent.policy.state_dict())
            print("Checkpoint saved")
            
            # Save model
            os.makedirs("model_weights_PPO", exist_ok=True)
            ppo_agent.save(f"model_weights_PPO/{name}_{episode+1}.pth")
    
    # Save final model and training statistics
    os.makedirs("model_weights_PPO", exist_ok=True)
    print(f'Saving final model')
    torch.save({
        'model_state_dict': ppo_agent.policy.state_dict(),
        'list_reward_p0': list_reward_p0,
        'list_reward_p1': list_reward_p1,
        'list_win_count_p0':list_win_count_p0,
        'list_draw_count': list_draw_count,
        'policy_checkpoints': policy_checkpoints,
        'num_checkpoints': len(policy_checkpoints)
    }, f"model_weights_PPO/{name}_final.pth")
    
    env.close()
    
    return list_reward_p0, list_reward_p1, list_win_count_p0, list_win_count_p1, list_draw_count

# %%
rewards_p0, rewards_p1, win_counts_p0, win_counts_p1, draw_counts = train_ppo_self_play("cathedral_ppo_self_play")
# Out:
# n_actions: 1753
# observation shape: (8, 8, 5)
# Episode 0
# Starting player: player_0
# /tmp/ipykernel_78980/203678370.py:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action_mask_tensor = torch.tensor(action_mask, dtype=torch.bool)
# score player 0 28 and player 1 23
# winner 1
# Timesteps of the episode 18
# Total rewards p0 -19 and p1 -18
# Episode 1
# Starting player: player_0
# score player 0 24 and player 1 27
# winner 0
# Timesteps of the episode 20
# Total rewards p0 -10 and p1 -24
# Episode 2
# Starting player: player_0
# score player 0 23 and player 1 24
# winner 0
# Timesteps of the episode 19
# Total rewards p0 -8 and p1 -13
# Episode 3
# Starting player: player_0
# score player 0 27 and player 1 22
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -20 and p1 -6
# Episode 4
# Starting player: player_0
# score player 0 32 and player 1 18
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -19 and p1 -8
# Episode 5
# Starting player: player_0
# score player 0 28 and player 1 22
# winner 1
# Timesteps of the episode 18
# Total rewards p0 -15 and p1 -14
# Episode 6
# Starting player: player_0
# score player 0 24 and player 1 21
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -16
# Episode 7
# Starting player: player_0
# score player 0 24 and player 1 23
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -11 and p1 -6
# Episode 8
# Starting player: player_0
# score player 0 26 and player 1 25
# winner 1
# Timesteps of the episode 17
# Total rewards p0 -18 and p1 -16
# Episode 9
# Starting player: player_0
# score player 0 30 and player 1 19
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -11 and p1 -4
# Episode 10
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -13 and p1 -15
# Episode 11
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -21 and p1 -20
# Episode 12
# Starting player: player_0
# score player 0 24 and player 1 19
# winner 1
# Timesteps of the episode 20
# Total rewards p0 -19 and p1 -19
# Episode 13
# Starting player: player_0
# score player 0 23 and player 1 22
# winner 1
# Timesteps of the episode 19
# Total rewards p0 -19 and p1 -20
# Episode 14
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 15
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 16
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 17
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 18
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 19
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 20
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 21
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 22
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 23
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 24
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 25
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 26
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 27
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 28
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 29
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 30
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 31
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 32
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 33
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 34
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 35
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 36
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 37
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 38
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 39
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 40
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 41
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 42
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 43
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 44
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 45
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 46
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 47
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 48
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 49
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 50
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 51
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 52
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 53
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 54
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 55
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 56
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 57
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 58
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 59
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 60
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 61
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 62
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 63
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 64
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 65
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 66
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 67
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 68
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 69
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 70
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 71
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 72
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 73
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 74
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 75
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 76
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 77
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 78
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 79
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 80
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 81
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 82
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 83
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 84
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 85
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 86
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 87
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 88
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 89
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 90
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 91
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 92
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 93
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 94
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 95
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 96
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 97
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 98
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 99
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 100/2500
#   Player 0 - Avg Reward: -17.69 - Win Rate: 0.02
#   Player 1 - Avg Reward: -20.05 - Win Rate: 0.1
#   Draw Rate: 0.88
# Episode 100
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 101
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 102
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 103
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 104
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 105
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 106
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 107
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 108
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 109
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 110
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 111
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 112
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 113
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 114
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 115
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 116
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 117
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 118
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 119
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 120
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 121
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 122
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 123
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 124
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 125
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 126
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 127
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 128
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 129
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 130
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 131
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 132
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 133
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 134
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 135
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 136
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 137
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 138
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 139
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 140
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 141
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 142
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 143
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 144
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 145
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 146
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 147
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 148
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 149
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 150
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 151
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 152
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 153
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 154
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 155
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 156
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 157
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 158
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 159
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 160
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 161
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 162
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 163
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 164
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 165
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 166
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 167
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 168
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 169
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 170
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 171
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 172
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 173
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 174
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 175
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 176
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 177
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 178
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 179
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 180
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 181
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 182
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 183
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 184
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 185
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 186
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 187
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 188
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 189
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 190
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 191
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 192
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 193
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 194
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 195
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 196
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 197
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 198
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 199
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 200/2500
#   Player 0 - Avg Reward: -18.00 - Win Rate: 0.01
#   Player 1 - Avg Reward: -21.00 - Win Rate: 0.05
#   Draw Rate: 0.94
# Episode 200
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 201
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 202
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 203
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 204
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 205
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 206
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 207
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 208
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 209
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 210
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 211
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 212
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 213
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 214
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 215
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 216
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 217
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 218
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 219
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 220
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 221
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 222
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 223
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 224
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 225
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 226
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 227
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 228
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 229
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 230
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 231
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 232
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 233
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 234
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 235
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 236
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 237
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 238
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 239
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 240
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 241
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 242
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 243
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 244
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 245
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 246
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 247
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 248
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 249
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 250
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 251
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 252
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 253
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 254
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 255
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 256
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 257
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 258
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 259
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 260
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 261
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 262
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 263
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 264
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 265
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 266
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 267
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 268
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 269
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 270
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 271
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 272
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 273
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 274
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 275
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 276
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 277
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 278
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 279
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 280
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 281
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 282
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 283
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 284
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 285
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 286
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 287
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 288
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 289
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 290
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 291
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 292
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 293
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 294
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 295
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 296
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 297
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 298
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 299
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 300/2500
#   Player 0 - Avg Reward: -18.00 - Win Rate: 0.006666666666666667
#   Player 1 - Avg Reward: -21.00 - Win Rate: 0.03333333333333333
#   Draw Rate: 0.96
# Episode 300
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 301
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 302
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 303
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 304
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 305
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 306
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 307
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 308
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 309
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 310
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 311
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 312
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 313
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 314
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 315
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 316
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 317
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 318
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 319
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 320
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 321
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 322
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 323
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 324
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 325
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 326
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 327
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 328
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 329
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 330
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 331
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 332
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 333
# Starting player: player_0
# ...
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2391
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2392
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2393
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2394
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2395
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2396
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2397
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2398
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2399
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2400/2500
#   Player 0 - Avg Reward: -18.00 - Win Rate: 0.0008333333333333334
#   Player 1 - Avg Reward: -21.00 - Win Rate: 0.004166666666666667
#   Draw Rate: 0.99
# Episode 2400
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2401
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2402
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2403
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2404
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2405
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2406
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2407
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2408
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2409
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2410
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2411
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2412
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2413
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2414
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2415
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2416
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2417
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2418
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2419
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2420
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2421
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2422
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2423
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2424
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2425
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2426
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2427
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2428
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2429
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2430
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2431
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2432
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2433
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2434
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2435
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2436
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2437
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2438
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2439
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2440
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2441
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2442
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2443
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2444
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2445
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2446
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2447
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2448
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2449
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2450
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2451
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2452
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2453
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2454
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2455
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2456
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2457
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2458
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2459
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2460
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2461
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2462
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2463
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2464
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2465
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2466
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2467
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2468
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2469
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2470
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2471
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2472
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2473
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2474
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2475
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2476
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2477
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2478
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2479
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2480
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2481
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2482
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2483
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2484
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2485
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2486
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2487
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2488
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2489
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2490
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2491
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2492
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2493
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2494
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2495
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2496
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2497
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2498
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2499
# Starting player: player_0
# score player 0 23 and player 1 23
# winner -1
# Timesteps of the episode 19
# Total rewards p0 -18 and p1 -21
# Episode 2500/2500
#   Player 0 - Avg Reward: -18.00 - Win Rate: 0.0008
#   Player 1 - Avg Reward: -21.00 - Win Rate: 0.004
#   Draw Rate: 1.00
# Checkpoint saved
# Saving final model

# %% [markdown]
# ### Playing against a random opponent

# %%
def train_ppo_random(name):
    env = cathedral_v0.env(board_size=board_size, render_mode="text", per_move_rewards=True, final_reward_score_difference=False)
    env.reset()
    
    # Get action space and observation shape (should be the same for both players)
    player_0 = "player_0"
    
    n_actions = env.action_space(player_0).n
    obs_shape = env.observe(player_0)["observation"].shape  # (10, 10, 5)
    
    print(f'n_actions: {n_actions}')
    print(f'observation shape: {obs_shape}')
    
    # Initialize PPO agent (will be used for both players)
    ppo_agent = PPO(
        obs_shape=obs_shape,
        action_dim=n_actions,
        lr_actor=lr_actor,
        lr_critic=lr_critic,
        gamma=gamma,
        K_epochs=K_epochs,
        eps_clip=eps_clip
    )
    
    # Training statistics
    list_reward_p0 = []
    list_reward_p1 = []
    policy_checkpoints = []
    list_win_count_p0 = [0]  # Initialize with 0
    list_win_count_p1 = [0]  # Initialize with 0
    list_draw_count = [0]    # Initialize with 0
    
    # Training loop
    for episode in range(num_episodes):
        print(f'Episode {episode}')
        env.reset()
        print(f"Starting player: {env.agent_selection}")
        total_reward_p0 = 0
        total_reward_p1 = 0
        episode_timesteps = 0
        
        # Clear player buffer
        ppo_agent.buffer.clear()
        
        # Run the game until completion
        while env.agents:  # Continue while there are still active agents
            current_agent = env.agent_selection
            episode_timesteps += 1
            observation = env.observe(current_agent)
            legal_moves = [i for i, valid in enumerate(observation["action_mask"]) if valid]
            
            if current_agent == player_0:  # PPO agent's turn
                
                state = observation["observation"]
                action_mask = observation["action_mask"]
                
                # Use PPO to select action
                action = ppo_agent.select_action(state, action_mask)
                
                # Take action in environment
                env.step(action)
                
                # Get reward and add to buffer
                reward = env.rewards[current_agent]
                print(f'reward {reward}')
                ppo_agent.buffer.rewards.append(reward)
                
                # Track total rewards
                total_reward_p0 += reward
                
                # Check if episode is done for this agent
                if current_agent not in env.agents:
                    ppo_agent.buffer.is_terminals.append(1)
                    print(f'Appended 1 to terminal')
                else:
                    ppo_agent.buffer.is_terminals.append(0)
                    print(f'Appended 0 to terminal')
                
            else:  # Random agent's turn
                observation = env.observe(current_agent)
                action_mask = observation["action_mask"]
                
                # Random valid action
        
                action = np.random.choice(legal_moves)
                
                # Take action in environment
                env.step(action)
                
                # Track total rewards (don't add to PPO buffer)
                reward = env.rewards[current_agent]
                print(f'reward {reward}')
                
                total_reward_p1 += reward
        
        # At this point, the game has ended
        print(f'Timesteps of the episode: {episode_timesteps}')
        
        if current_agent == player_0:
            # We've already counted player_0's reward, but we need to account for player_1's final reward
            total_reward_p1 += env.rewards["player_1"]
        else:
            # We've already counted player_1's reward, but we need to account for player_0's final reward
            total_reward_p0 += env.rewards["player_0"]
            # Also update the PPO buffer with the correct final reward
            if ppo_agent.buffer.rewards and len(ppo_agent.buffer.rewards) > 0:
                # Replace the last "0" reward with the actual final reward
                ppo_agent.buffer.rewards[-1] = env.rewards["player_0"]
                ppo_agent.buffer.is_terminals[-1] = 1
            
        ppo_agent.update()
        
        # Collect statistics
        print(f'Total rewards p0 {total_reward_p0} and p1 {total_reward_p1}')
        list_reward_p0.append(total_reward_p0)
        list_reward_p1.append(total_reward_p1)
        
        # Update the appropriate counter based on the game outcome
        if env.winner == 0:  # player_0 wins
            list_win_count_p0.append(list_win_count_p0[-1] + 1)
            list_win_count_p1.append(list_win_count_p1[-1])  # Carry forward p1 count unchanged
            list_draw_count.append(list_draw_count[-1])  # Carry forward draw count unchanged
            
        elif env.winner == 1:  # player_1 wins
            list_win_count_p0.append(list_win_count_p0[-1])  # Carry forward p0 count unchanged
            list_win_count_p1.append(list_win_count_p1[-1] + 1)
            list_draw_count.append(list_draw_count[-1])  # Carry forward draw count unchanged
            
        elif env.winner == -1:  # draw
            list_win_count_p0.append(list_win_count_p0[-1])  # Carry forward p0 count unchanged
            list_win_count_p1.append(list_win_count_p1[-1])  # Carry forward p1 count unchanged
            list_draw_count.append(list_draw_count[-1] + 1)
        
        if (episode + 1) % 100 == 0:
            win_rate_p0 = list_win_count_p0[-1] / (episode + 1)
            win_rate_p1 = list_win_count_p1[-1] / (episode + 1)
            draw_rate = list_draw_count[-1] / (episode + 1)
            
            print(f"Episode {episode+1}/{num_episodes}")
            print(f"  Player 0 - Avg Reward: {sum(list_reward_p0[-100:]) / 100:.2f} - Win Rate: {win_rate_p0}")
            print(f"  Player 1 - Avg Reward: {sum(list_reward_p1[-100:]) / 100:.2f} - Win Rate: {win_rate_p1}")
            print(f"  Draw Rate: {draw_rate:.2f}")
            
        # Save checkpoint
        if (episode+1) % 500 == 0:
            policy_checkpoints.append(ppo_agent.policy.state_dict())
            print("Checkpoint saved")
            
            # Save model
            os.makedirs("model_weights_PPO", exist_ok=True)
            ppo_agent.save(f"model_weights_PPO/{name}_{episode+1}.pth")
    
    # Save final model and training statistics
    os.makedirs("model_weights_random_PPO", exist_ok=True)
    print(f'Saving final model')
    torch.save({
        'model_state_dict': ppo_agent.policy.state_dict(),
        'list_reward_p0': list_reward_p0,
        'list_reward_p1': list_reward_p1,
        'list_win_count_p0':list_win_count_p0,
        'list_win_count_p1':list_win_count_p1, 
        'list_draw_count': list_draw_count,
        'policy_checkpoints': policy_checkpoints,
        'num_checkpoints': len(policy_checkpoints)
    }, f"model_weights_random_PPO/{name}_final.pth")
    
    env.close()
    
    return list_reward_p0, list_reward_p1, list_win_count_p0, list_win_count_p1, list_draw_count

# %%
rewards_p0, rewards_p1, win_counts_p0, win_counts_p1, draw_counts = train_ppo_random("cathedral_ppo_vs_random")

# %%
# Plot results
plt.figure(figsize=(15, 10))

# Plot rewards for both players
plt.subplot(2, 2, 1)
plt.plot(rewards_p0, label='Player 0', alpha=0.7)
plt.plot(rewards_p1, label='Player 1', alpha=0.7)
plt.title("Rewards per Episode")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()

# Plot moving average of rewards for better visualization
window = 100
plt.subplot(2, 2, 2)
p0_avg = [np.mean(rewards_p0[max(0, i-window):i+1]) for i in range(len(rewards_p0))]
p1_avg = [np.mean(rewards_p1[max(0, i-window):i+1]) for i in range(len(rewards_p1))]
plt.plot(p0_avg, label='Player 0 (100-ep avg)', alpha=0.7)
plt.plot(p1_avg, label='Player 1 (100-ep avg)', alpha=0.7)
plt.title("Moving Average Rewards (100 episodes)")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.legend()

# Plot win rates for player 0
plt.subplot(2, 2, 3)

# Start from episode 1 to avoid division by zero
start_idx = 1  # Skip episode 0

# Calculate win rates as a function of episodes played
total_games = [i + 1 for i in range(len(win_counts_p0))]  # Assuming one entry per game
p0_win_rates = [wins / games for wins, games in zip(win_counts_p0, total_games)]
p1_win_rates = [wins / games for wins, games in zip(win_counts_p1, total_games)]
draw_rates = [draws / games for draws, games in zip(draw_counts, total_games)]

# Plot with matching dimensions
plt.plot(range(len(p0_win_rates)), p0_win_rates, marker='', label='Player 0 Win Rate', color='blue')
plt.plot(range(len(p1_win_rates)), p1_win_rates, marker='', label='Player 1 Win Rate', color='orange')
plt.plot(range(len(draw_rates)), draw_rates, marker='', label='Draw Rate', color='green')
plt.title("Cumulative Win/Draw Rates")
plt.xlabel("Episode")
plt.ylabel("Rate")
plt.ylim(0, 1)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig("ppo_self_play_training_results.png")
plt.show()

# %%
def evaluate_ppo_against_random(model_path, num_episodes=100, board_size=10, render=False):
    """
    Evaluate a trained PPO agent against a random policy.
    
    Args:
        model_path (str): Path to the saved PPO model weights
        num_episodes (int): Number of evaluation episodes
        board_size (int): Size of the board
        render (bool): Whether to render the game
        
    Returns:
        dict: Evaluation metrics including win rate
    """
    env = cathedral_v0.env(
        board_size=board_size, 
        render_mode="ansi" if render else None, 
        per_move_rewards=True, 
        final_reward_score_difference=False
    )
    env.reset()
    
    # Get observation shape and action space
    player_0 = "player_0"  # PPO agent
    player_1 = "player_1"  # Random agent
    n_actions = env.action_space(player_0).n
    obs_shape = env.observe(player_0)["observation"].shape
    
    print(f"Loading model from {model_path}")
    
    # Initialize PPO agent
    ppo_agent = PPO(
        obs_shape=obs_shape,
        action_dim=n_actions,
        lr_actor=0.0005,  # These values don't matter for evaluation
        lr_critic=0.003,
        gamma=0.95,
        K_epochs=4,
        eps_clip=0.2
    )
    
    # Load model weights
    checkpoint = torch.load(model_path, weights_only=False)

    # Check if this is a dictionary with 'model_state_dict' key (from training function)
    if 'model_state_dict' in checkpoint:
        ppo_agent.policy.load_state_dict(checkpoint['model_state_dict'])
    else:
        # Direct state dict (from .save() method)
        ppo_agent.policy.load_state_dict(checkpoint)
    
    # Set to evaluation mode
    ppo_agent.policy.eval()
    
    # Statistics
    stats = {
        'ppo_wins': 0,
        'random_wins': 0,
        'draws': 0,
        'ppo_rewards': [],
        'random_rewards': [],
    }
    
    for episode in range(num_episodes):
        env.reset()
        done = False
        episode_reward_ppo = 0
        episode_reward_random = 0
        
        # Print progress
        if episode % 10 == 0:
            print(f"Playing episode {episode}/{num_episodes}")
        
        while env.agents:
            current_agent = env.agent_selection
            
            if current_agent == player_1:  # PPO agent's turn
                observation = env.observe(current_agent)
                state = observation["observation"]
                action_mask = observation["action_mask"]
                
                # Use PPO to select action (deterministic for evaluation)
                with torch.no_grad():
                    action = ppo_agent.select_action(state, action_mask)
                    print(f'PPO action {action}')
                
            else:  # Random agent's turn
                observation = env.observe(current_agent)
                action_mask = observation["action_mask"]
                
                # Random valid action
                valid_actions = np.where(action_mask == 1)[0]
                action = np.random.choice(valid_actions)
                print(f'Random action {action}')
            
            # Take action
            env.step(action)
            
            # Track rewards
            if current_agent == player_1:
                episode_reward_ppo += env.rewards[current_agent]
            else:
                episode_reward_random += env.rewards[current_agent]
            
            # Render if needed
            if render and episode % 10 == 0:
                print(env.render())
        
        print(f'Episode {episode} winner {env.winner}')
        # Record game outcome
        if env.winner == 1:  # PPO agent won
            stats['ppo_wins'] += 1
        elif env.winner == 0:  # Random agent won
            stats['random_wins'] += 1
        else:  # Draw
            stats['draws'] += 1
        
        # Record episode rewards
        stats['ppo_rewards'].append(episode_reward_ppo)
        stats['random_rewards'].append(episode_reward_random)
    
    # Calculate win rates
    stats['ppo_win_rate'] = stats['ppo_wins'] / num_episodes
    stats['random_win_rate'] = stats['random_wins'] / num_episodes
    stats['draw_rate'] = stats['draws'] / num_episodes
    
    # Calculate average rewards
    stats['avg_ppo_reward'] = sum(stats['ppo_rewards']) / num_episodes
    stats['avg_random_reward'] = sum(stats['random_rewards']) / num_episodes
    
    # Print summary
    print("\n===== Evaluation Results =====")
    print(f"Episodes played: {num_episodes}")
    print(f"PPO Wins: {stats['ppo_wins']} ({stats['ppo_win_rate']:.2%})")
    print(f"Random Wins: {stats['random_wins']} ({stats['random_win_rate']:.2%})")
    print(f"Draws: {stats['draws']} ({stats['draw_rate']:.2%})")
    print(f"Average PPO Reward: {stats['avg_ppo_reward']:.2f}")
    print(f"Average Random Reward: {stats['avg_random_reward']:.2f}")
    
    env.close()
    return stats

# %%
model_path = "model_weights_PPO/cathedral_ppo_self_play_final.pth"  # Update with your model path

eval_stats = evaluate_ppo_against_random(
    model_path=model_path,
    num_episodes=100,
    board_size=8,
    render=False  # Set to True to visualize some games
)

# Create a bar chart of win rates
labels = ['PPO Agent', 'Random Agent', 'Draw']
values = [eval_stats['ppo_win_rate'], eval_stats['random_win_rate'], eval_stats['draw_rate']]
colors = ['green', 'red', 'gray']

plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=colors)
plt.title('Win Rate Comparison')
plt.ylabel('Win Rate')
plt.ylim(0, 1)

for i, v in enumerate(values):
    plt.text(i, v + 0.02, f'{v:.2%}', ha='center')

plt.tight_layout()
plt.savefig('ppo_vs_random_evaluation.png')
plt.show()
# Out:
# Loading model from model_weights_PPO/cathedral_ppo_self_play_final.pth
# Playing episode 0/100
# Random action 1686
# /tmp/ipykernel_78980/203678370.py:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action_mask_tensor = torch.tensor(action_mask, dtype=torch.bool)
# PPO action 96
# Random action 836
# PPO action 1005
# Random action 622
# PPO action 1151
# Random action 1346
# PPO action 495
# Random action 1605
# PPO action 333
# Random action 90
# PPO action 15
# Random action 51
# PPO action 569
# Random action 344
# PPO action 141
# Random action 219
# PPO action 795
# Random action 352
# Random action 238
# score player 0 22 and player 1 23
# winner 0
# Episode 0 winner 0
# Random action 1687
# PPO action 236
# Random action 704
# PPO action 452
# Random action 1500
# PPO action 919
# Random action 117
# PPO action 120
# Random action 316
# PPO action 715
# Random action 956
# PPO action 1291
# Random action 30
# PPO action 47
# Random action 546
# PPO action 96
# Random action 791
# PPO action 240
# Random action 136
# score player 0 23 and player 1 26
# winner 0
# Episode 1 winner 0
# Random action 1745
# PPO action 705
# Random action 1181
# PPO action 236
# Random action 1059
# PPO action 240
# Random action 398
# PPO action 292
# Random action 127
# PPO action 36
# Random action 1406
# PPO action 363
# Random action 200
# PPO action 108
# Random action 23
# PPO action 792
# Random action 744
# Random action 700
# Random action 274
# Random action 846
# score player 0 14 and player 1 35
# winner 0
# Episode 2 winner 0
# Random action 1655
# PPO action 1423
# Random action 438
# PPO action 1087
# Random action 1035
# PPO action 238
# Random action 1189
# PPO action 117
# Random action 561
# PPO action 360
# Random action 875
# PPO action 21
# Random action 834
# PPO action 307
# Random action 19
# PPO action 833
# Random action 295
# PPO action 548
# Random action 80
# Random action 139
# score player 0 19 and player 1 23
# winner 0
# Episode 3 winner 0
# Random action 1740
# PPO action 935
# Random action 87
# PPO action 888
# Random action 192
# PPO action 13
# Random action 1058
# PPO action 503
# Random action 296
# PPO action 326
# Random action 776
# PPO action 1060
# Random action 425
# PPO action 160
# Random action 60
# PPO action 811
# Random action 561
# PPO action 91
# PPO action 548
# score player 0 28 and player 1 20
# winner 1
# Episode 4 winner 1
# Random action 1660
# PPO action 1278
# Random action 1192
# PPO action 479
# Random action 708
# PPO action 564
# Random action 187
# PPO action 217
# Random action 379
# PPO action 2
# Random action 291
# PPO action 1074
# Random action 100
# PPO action 313
# Random action 56
# PPO action 99
# Random action 750
# PPO action 811
# score player 0 27 and player 1 23
# winner 1
# Episode 5 winner 1
# Random action 1655
# PPO action 1397
# Random action 65
# PPO action 34
# Random action 1276
# PPO action 335
# Random action 265
# PPO action 839
# Random action 134
# PPO action 1028
# Random action 12
# PPO action 395
# Random action 491
# PPO action 230
# Random action 600
# PPO action 701
# Random action 792
# PPO action 86
# score player 0 27 and player 1 23
# winner 1
# Episode 6 winner 1
# Random action 1752
# PPO action 934
# Random action 623
# PPO action 1471
# Random action 983
# PPO action 185
# Random action 57
# PPO action 392
# Random action 1239
# PPO action 749
# Random action 1079
# PPO action 101
# Random action 129
# PPO action 243
# Random action 357
# PPO action 50
# Random action 66
# Random action 316
# score player 0 22 and player 1 26
# winner 0
# Episode 7 winner 0
# Random action 1710
# PPO action 55
# Random action 1144
# PPO action 153
# Random action 1088
# PPO action 739
# Random action 49
# PPO action 1336
# Random action 106
# PPO action 820
# Random action 781
# PPO action 85
# Random action 713
# PPO action 286
# Random action 215
# PPO action 365
# Random action 303
# Random action 546
# score player 0 23 and player 1 28
# winner 0
# Episode 8 winner 0
# Random action 1721
# PPO action 1067
# Random action 1109
# PPO action 760
# Random action 230
# PPO action 108
# Random action 1471
# PPO action 675
# Random action 645
# PPO action 29
# Random action 24
# PPO action 129
# Random action 393
# PPO action 360
# Random action 122
# PPO action 242
# Random action 874
# PPO action 882
# Random action 351
# score player 0 22 and player 1 24
# winner 0
# Episode 9 winner 0
# Playing episode 10/100
# Random action 1645
# PPO action 819
# Random action 655
# PPO action 1603
# Random action 823
# PPO action 1059
# Random action 350
# PPO action 534
# Random action 91
# PPO action 9
# Random action 158
# PPO action 70
# Random action 43
# PPO action 241
# Random action 482
# PPO action 618
# Random action 1378
# PPO action 162
# score player 0 27 and player 1 23
# winner 1
# Episode 10 winner 1
# Random action 1741
# PPO action 187
# Random action 24
# PPO action 9
# Random action 543
# PPO action 1349
# Random action 806
# PPO action 991
# Random action 956
# PPO action 750
# Random action 592
# PPO action 76
# Random action 328
# PPO action 375
# Random action 123
# PPO action 333
# Random action 171
# PPO action 718
# score player 0 28 and player 1 23
# winner 1
# Episode 11 winner 1
# Random action 1646
# PPO action 821
# Random action 443
# PPO action 270
# Random action 1039
# PPO action 499
# Random action 1565
# PPO action 1145
# Random action 96
# PPO action 6
# Random action 779
# PPO action 172
# Random action 197
# PPO action 888
# Random action 59
# PPO action 71
# Random action 316
# PPO action 672
# Random action 1130
# score player 0 22 and player 1 26
# winner 0
# Episode 12 winner 0
# Random action 1684
# PPO action 1053
# Random action 455
# PPO action 395
# Random action 1626
# PPO action 586
# Random action 1404
# PPO action 1335
# Random action 218
# PPO action 104
# Random action 881
# PPO action 308
# Random action 809
# PPO action 21
# Random action 69
# PPO action 152
# Random action 120
# Random action 63
# Random action 335
# Random action 736
# score player 0 18 and player 1 30
# winner 0
# Episode 13 winner 0
# Random action 1751
# PPO action 17
# Random action 1241
# PPO action 606
# Random action 307
# PPO action 415
# Random action 142
# PPO action 239
# Random action 899
# PPO action 1099
# Random action 874
# PPO action 1537
# Random action 108
# PPO action 748
# Random action 58
# PPO action 271
# Random action 730
# PPO action 123
# Random action 358
# score player 0 22 and player 1 23
# winner 0
# Episode 14 winner 0
# Random action 1716
# PPO action 1058
# Random action 958
# PPO action 759
# Random action 546
# PPO action 670
# Random action 68
# PPO action 212
# Random action 337
# PPO action 282
# Random action 21
# PPO action 125
# Random action 854
# PPO action 439
# Random action 217
# PPO action 15
# Random action 692
# Random action 749
# score player 0 24 and player 1 28
# winner 0
# Episode 15 winner 0
# Random action 1712
# PPO action 1064
# Random action 315
# PPO action 247
# Random action 940
# PPO action 392
# Random action 780
# PPO action 1032
# Random action 525
# PPO action 209
# Random action 32
# PPO action 629
# Random action 72
# PPO action 12
# Random action 187
# PPO action 86
# Random action 736
# PPO action 748
# score player 0 28 and player 1 24
# winner 1
# Episode 16 winner 1
# Random action 1662
# PPO action 244
# Random action 777
# PPO action 198
# Random action 158
# PPO action 883
# Random action 328
# PPO action 425
# Random action 661
# PPO action 548
# Random action 516
# PPO action 796
# Random action 63
# PPO action 93
# Random action 1062
# PPO action 999
# Random action 117
# PPO action 60
# score player 0 28 and player 1 24
# winner 1
# Episode 17 winner 1
# Random action 1714
# PPO action 887
# Random action 288
# PPO action 301
# Random action 147
# PPO action 1615
# Random action 631
# PPO action 401
# Random action 1061
# PPO action 196
# Random action 124
# PPO action 119
# Random action 52
# PPO action 1
# Random action 367
# PPO action 45
# Random action 746
# PPO action 763
# PPO action 735
# score player 0 28 and player 1 23
# winner 1
# Episode 18 winner 1
# Random action 1654
# PPO action 1598
# Random action 1407
# PPO action 919
# Random action 86
# PPO action 221
# Random action 727
# PPO action 772
# Random action 992
# PPO action 66
# Random action 867
# PPO action 348
# Random action 58
# PPO action 48
# Random action 350
# PPO action 378
# Random action 222
# PPO action 548
# score player 0 25 and player 1 23
# winner 1
# Episode 19 winner 1
# Playing episode 20/100
# Random action 1745
# PPO action 794
# Random action 1199
# PPO action 894
# Random action 269
# PPO action 474
# Random action 843
# PPO action 103
# Random action 506
# PPO action 281
# Random action 1489
# PPO action 690
# Random action 111
# PPO action 42
# Random action 836
# PPO action 178
# Random action 57
# Random action 548
# Random action 174
# score player 0 18 and player 1 28
# winner 0
# Episode 20 winner 0
# Random action 1665
# PPO action 831
# Random action 1067
# PPO action 236
# Random action 210
# PPO action 333
# Random action 116
# PPO action 863
# Random action 820
# PPO action 78
# Random action 4
# PPO action 505
# Random action 350
# PPO action 1213
# Random action 566
# PPO action 45
# Random action 749
# PPO action 616
# Random action 410
# score player 0 28 and player 1 23
# winner 1
# Episode 21 winner 1
# Random action 1687
# PPO action 249
# Random action 158
# PPO action 1293
# Random action 687
# PPO action 704
# Random action 303
# PPO action 96
# Random action 1074
# PPO action 355
# Random action 71
# PPO action 0
# Random action 62
# PPO action 885
# Random action 500
# PPO action 229
# Random action 796
# PPO action 1100
# PPO action 820
# score player 0 28 and player 1 19
# winner 1
# Episode 22 winner 1
# Random action 1708
# PPO action 48
# Random action 141
# PPO action 241
# Random action 779
# PPO action 1390
# Random action 1612
# PPO action 551
# Random action 743
# PPO action 885
# Random action 851
# PPO action 29
# Random action 109
# PPO action 752
# Random action 282
# PPO action 95
# Random action 11
# PPO action 209
# Random action 524
# score player 0 23 and player 1 26
# winner 0
# Episode 23 winner 0
# Random action 1740
# PPO action 139
# Random action 328
# PPO action 1624
# Random action 758
# PPO action 432
# Random action 352
# PPO action 645
# Random action 190
# PPO action 1075
# Random action 570
# PPO action 855
# Random action 103
# PPO action 75
# Random action 59
# PPO action 271
# Random action 993
# PPO action 63
# score player 0 28 and player 1 22
# winner 1
# Episode 24 winner 1
# Random action 1660
# PPO action 1256
# Random action 765
# PPO action 749
# Random action 358
# PPO action 1315
# Random action 628
# PPO action 33
# Random action 257
# PPO action 1622
# Random action 106
# PPO action 284
# Random action 129
# PPO action 103
# Random action 26
# PPO action 729
# PPO action 174
# score player 0 32 and player 1 20
# winner 1
# Episode 25 winner 1
# Random action 1736
# PPO action 272
# Random action 1381
# PPO action 1486
# Random action 333
# PPO action 631
# Random action 811
# PPO action 940
# Random action 375
# PPO action 420
# Random action 12
# PPO action 3
# Random action 104
# PPO action 191
# Random action 840
# PPO action 99
# Random action 136
# PPO action 7
# Random action 587
# PPO action 16
# PPO action 833
# score player 0 23 and player 1 23
# winner -1
# Episode 26 winner -1
# Random action 1635
# PPO action 1113
# Random action 1269
# PPO action 918
# Random action 1379
# PPO action 499
# Random action 465
# PPO action 315
# Random action 127
# PPO action 87
# Random action 25
# PPO action 128
# Random action 702
# PPO action 604
# Random action 289
# PPO action 54
# Random action 203
# PPO action 248
# score player 0 25 and player 1 27
# winner 0
# Episode 27 winner 0
# Random action 1649
# PPO action 436
# Random action 311
# PPO action 1534
# Random action 1126
# PPO action 244
# Random action 1588
# PPO action 129
# Random action 730
# PPO action 736
# Random action 65
# PPO action 27
# Random action 157
# PPO action 117
# Random action 359
# PPO action 1120
# Random action 20
# PPO action 839
# score player 0 26 and player 1 23
# winner 1
# Episode 28 winner 1
# Random action 1726
# PPO action 593
# Random action 106
# PPO action 76
# Random action 545
# PPO action 179
# Random action 1409
# PPO action 57
# Random action 549
# PPO action 1508
# Random action 906
# PPO action 1053
# Random action 7
# PPO action 284
# Random action 331
# PPO action 481
# Random action 39
# PPO action 1098
# Random action 194
# PPO action 833
# Random action 241
# score player 0 26 and player 1 19
# winner 1
# Episode 29 winner 1
# Playing episode 30/100
# Random action 1699
# PPO action 537
# Random action 1273
# PPO action 615
# Random action 1340
# PPO action 101
# Random action 365
# PPO action 874
# Random action 351
# PPO action 218
# Random action 751
# PPO action 59
# Random action 88
# PPO action 300
# Random action 40
# PPO action 745
# Random action 195
# Random action 723
# score player 0 22 and player 1 28
# winner 0
# Episode 30 winner 0
# Random action 1682
# PPO action 1125
# Random action 1342
# PPO action 1463
# Random action 364
# PPO action 200
# Random action 654
# PPO action 1513
# Random action 107
# PPO action 61
# Random action 744
# PPO action 888
# Random action 301
# PPO action 120
# Random action 42
# PPO action 256
# Random action 157
# PPO action 661
# score player 0 27 and player 1 20
# winner 1
# Episode 31 winner 1
# Random action 1680
# PPO action 65
# Random action 776
# PPO action 1083
# Random action 987
# PPO action 725
# Random action 1562
# PPO action 477
# Random action 9
# PPO action 135
# Random action 112
# PPO action 6
# Random action 717
# PPO action 834
# Random action 129
# PPO action 248
# Random action 332
# PPO action 817
# score player 0 26 and player 1 28
# winner 0
# Episode 32 winner 0
# Random action 1744
# PPO action 1174
# Random action 1308
# PPO action 550
# Random action 1045
# PPO action 232
# Random action 1326
# PPO action 1382
# Random action 58
# PPO action 822
# Random action 1204
# PPO action 244
# Random action 616
# PPO action 88
# Random action 237
# PPO action 34
# Random action 249
# PPO action 219
# Random action 114
# Random action 833
# score player 0 16 and player 1 25
# winner 0
# Episode 33 winner 0
# Random action 1721
# PPO action 126
# Random action 715
# PPO action 373
# Random action 815
# PPO action 771
# Random action 421
# PPO action 161
# Random action 121
# PPO action 582
# Random action 247
# PPO action 16
# Random action 341
# PPO action 867
# Random action 54
# PPO action 961
# Random action 506
# PPO action 267
# Random action 217
# PPO action 86
# score player 0 32 and player 1 24
# winner 1
# Episode 34 winner 1
# Random action 1647
# PPO action 1063
# Random action 713
# PPO action 175
# Random action 221
# PPO action 634
# Random action 1582
# PPO action 492
# Random action 868
# PPO action 745
# Random action 755
# PPO action 1488
# Random action 118
# PPO action 83
# Random action 58
# PPO action 43
# Random action 271
# PPO action 299
# Random action 362
# score player 0 23 and player 1 23
# winner -1
# Episode 35 winner -1
# Random action 1725
# PPO action 1506
# Random action 1482
# PPO action 1167
# Random action 41
# PPO action 75
# Random action 87
# PPO action 506
# Random action 636
# PPO action 244
# Random action 349
# PPO action 33
# Random action 477
# PPO action 792
# Random action 167
# PPO action 722
# Random action 749
# PPO action 235
# score player 0 27 and player 1 22
# winner 1
# Episode 36 winner 1
# Random action 1665
# PPO action 129
# Random action 648
# PPO action 554
# Random action 112
# PPO action 495
# Random action 1521
# PPO action 1605
# Random action 159
# PPO action 115
# Random action 5
# PPO action 50
# Random action 260
# PPO action 268
# Random action 838
# PPO action 1051
# Random action 365
# PPO action 752
# score player 0 27 and player 1 23
# winner 1
# Episode 37 winner 1
# Random action 1751
# PPO action 1237
# Random action 580
# PPO action 355
# Random action 23
# PPO action 561
# Random action 1141
# PPO action 236
# Random action 111
# PPO action 1569
# Random action 850
# PPO action 86
# Random action 997
# PPO action 248
# Random action 287
# PPO action 63
# Random action 834
# PPO action 778
# score player 0 24 and player 1 22
# winner 1
# Episode 38 winner 1
# Random action 1681
# PPO action 1301
# Random action 1240
# PPO action 1038
# Random action 766
# PPO action 142
# Random action 532
# PPO action 346
# Random action 6
# PPO action 362
# Random action 215
# PPO action 744
# Random action 88
# PPO action 59
# Random action 312
# PPO action 67
# Random action 1087
# PPO action 144
# Random action 714
# score player 0 23 and player 1 26
# winner 0
# Episode 39 winner 0
# Playing episode 40/100
# Random action 1688
# PPO action 1490
# Random action 574
# PPO action 350
# Random action 1304
# PPO action 1463
# Random action 365
# PPO action 16
# Random action 329
# PPO action 668
# Random action 1536
# PPO action 127
# Random action 69
# PPO action 1018
# Random action 331
# PPO action 130
# Random action 203
# PPO action 533
# Random action 21
# score player 0 25 and player 1 21
# winner 1
# Episode 40 winner 1
# Random action 1682
# PPO action 723
# Random action 747
# PPO action 1384
# Random action 133
# PPO action 366
# Random action 476
# PPO action 807
# Random action 345
# PPO action 86
# Random action 123
# PPO action 309
# Random action 6
# PPO action 13
# Random action 1622
# PPO action 220
# Random action 650
# PPO action 920
# score player 0 27 and player 1 23
# winner 1
# Episode 41 winner 1
# Random action 1680
# PPO action 1254
# Random action 1058
# PPO action 1373
# Random action 99
# PPO action 208
# Random action 731
# PPO action 645
# Random action 5
# PPO action 79
# Random action 210
# PPO action 921
# Random action 839
# PPO action 38
# Random action 303
# PPO action 262
# Random action 533
# PPO action 836
# score player 0 28 and player 1 21
# winner 1
# Episode 42 winner 1
# Random action 1748
# PPO action 1545
# Random action 846
# PPO action 970
# Random action 74
# PPO action 337
# Random action 221
# PPO action 498
# Random action 1116
# PPO action 144
# Random action 806
# PPO action 87
# Random action 1172
# PPO action 60
# Random action 555
# PPO action 549
# Random action 299
# Random action 36
# score player 0 22 and player 1 26
# winner 0
# Episode 43 winner 0
# Random action 1647
# PPO action 570
# Random action 741
# PPO action 1467
# Random action 931
# PPO action 833
# Random action 1570
# PPO action 535
# Random action 135
# PPO action 189
# Random action 1
# PPO action 36
# Random action 80
# PPO action 326
# Random action 426
# PPO action 76
# Random action 254
# PPO action 1111
# score player 0 26 and player 1 23
# winner 1
# Episode 44 winner 1
# Random action 1747
# PPO action 1176
# Random action 302
# PPO action 867
# Random action 1050
# PPO action 1350
# Random action 549
# PPO action 113
# Random action 820
# PPO action 512
# Random action 123
# PPO action 590
# Random action 740
# PPO action 181
# Random action 57
# PPO action 7
# Random action 175
# PPO action 753
# PPO action 244
# score player 0 31 and player 1 18
# winner 1
# Episode 45 winner 1
# Random action 1651
# PPO action 823
# Random action 1384
# PPO action 312
# Random action 1313
# PPO action 940
# Random action 156
# PPO action 122
# Random action 747
# PPO action 546
# Random action 738
# PPO action 48
# Random action 297
# PPO action 189
# Random action 28
# PPO action 561
# Random action 97
# score player 0 25 and player 1 28
# winner 0
# Episode 46 winner 0
# Random action 1748
# PPO action 132
# Random action 1031
# PPO action 331
# Random action 1112
# PPO action 1076
# Random action 23
# PPO action 653
# Random action 1351
# PPO action 961
# Random action 88
# PPO action 40
# Random action 131
# PPO action 85
# Random action 264
# PPO action 406
# Random action 644
# PPO action 837
# score player 0 25 and player 1 24
# winner 1
# Episode 47 winner 1
# Random action 1744
# PPO action 860
# Random action 1194
# PPO action 935
# Random action 672
# PPO action 707
# Random action 1058
# PPO action 63
# Random action 1450
# PPO action 88
# Random action 233
# PPO action 1140
# Random action 844
# PPO action 129
# Random action 104
# PPO action 270
# Random action 365
# Random action 29
# score player 0 19 and player 1 26
# winner 0
# Episode 48 winner 0
# Random action 1736
# PPO action 923
# Random action 247
# PPO action 1470
# Random action 1071
# PPO action 1057
# Random action 69
# PPO action 450
# Random action 509
# PPO action 28
# Random action 863
# PPO action 337
# Random action 6
# PPO action 106
# Random action 239
# PPO action 588
# Random action 608
# PPO action 217
# score player 0 27 and player 1 22
# winner 1
# Episode 49 winner 1
# Playing episode 50/100
# Random action 1707
# PPO action 1536
# Random action 891
# PPO action 482
# Random action 729
# PPO action 1064
# Random action 186
# PPO action 140
# Random action 347
# PPO action 319
# Random action 124
# PPO action 882
# Random action 25
# PPO action 1277
# Random action 394
# PPO action 76
# PPO action 63
# PPO action 655
# score player 0 31 and player 1 17
# winner 1
# Episode 50 winner 1
# Random action 1685
# PPO action 497
# Random action 1582
# PPO action 1091
# Random action 346
# PPO action 39
# Random action 745
# PPO action 237
# Random action 13
# PPO action 1001
# Random action 157
# PPO action 562
# Random action 88
# PPO action 337
# Random action 528
# PPO action 107
# Random action 304
# PPO action 762
# Random action 1067
# PPO action 1483
# score player 0 26 and player 1 19
# winner 1
# Episode 51 winner 1
# Random action 1649
# PPO action 1451
# Random action 452
# PPO action 208
# Random action 1345
# PPO action 806
# Random action 1034
# PPO action 119
# Random action 297
# PPO action 53
# Random action 179
# PPO action 243
# Random action 61
# PPO action 561
# Random action 126
# PPO action 891
# Random action 731
# Random action 788
# score player 0 23 and player 1 26
# winner 0
# Episode 52 winner 0
# Random action 1671
# PPO action 139
# Random action 529
# PPO action 996
# Random action 1464
# PPO action 712
# Random action 330
# PPO action 1142
# Random action 762
# PPO action 119
# Random action 635
# PPO action 495
# Random action 142
# PPO action 349
# Random action 56
# PPO action 2
# Random action 96
# PPO action 843
# PPO action 791
# score player 0 30 and player 1 19
# winner 1
# Episode 53 winner 1
# Random action 1671
# PPO action 376
# Random action 296
# PPO action 1273
# Random action 1458
# PPO action 65
# Random action 594
# PPO action 63
# Random action 155
# PPO action 1426
# Random action 21
# PPO action 195
# Random action 118
# PPO action 551
# Random action 748
# PPO action 241
# Random action 450
# PPO action 786
# score player 0 27 and player 1 22
# winner 1
# Episode 54 winner 1
# Random action 1667
# PPO action 1216
# Random action 502
# PPO action 173
# Random action 219
# PPO action 1058
# Random action 322
# PPO action 541
# Random action 805
# PPO action 35
# Random action 40
# PPO action 94
# Random action 117
# PPO action 724
# Random action 600
# PPO action 346
# Random action 1327
# PPO action 1352
# Random action 986
# score player 0 23 and player 1 21
# winner 1
# Episode 55 winner 1
# Random action 1713
# PPO action 844
# Random action 959
# PPO action 889
# Random action 1475
# PPO action 42
# Random action 140
# PPO action 615
# Random action 31
# PPO action 259
# Random action 795
# PPO action 72
# Random action 218
# PPO action 396
# Random action 334
# PPO action 203
# Random action 700
# PPO action 778
# Random action 123
# score player 0 26 and player 1 24
# winner 1
# Episode 56 winner 1
# Random action 1671
# PPO action 189
# Random action 812
# PPO action 688
# Random action 202
# PPO action 257
# Random action 2
# PPO action 824
# Random action 579
# PPO action 31
# Random action 1049
# PPO action 409
# Random action 303
# PPO action 1296
# Random action 123
# PPO action 71
# Random action 395
# PPO action 882
# PPO action 993
# score player 0 28 and player 1 19
# winner 1
# Episode 57 winner 1
# Random action 1653
# PPO action 893
# Random action 328
# PPO action 711
# Random action 1120
# PPO action 199
# Random action 58
# PPO action 1068
# Random action 1206
# PPO action 64
# Random action 506
# PPO action 39
# Random action 65
# PPO action 388
# Random action 838
# PPO action 284
# Random action 647
# PPO action 833
# Random action 847
# PPO action 121
# Random action 203
# score player 0 19 and player 1 24
# winner 0
# Episode 58 winner 0
# Random action 1722
# PPO action 616
# Random action 1324
# PPO action 995
# Random action 543
# PPO action 1079
# Random action 290
# PPO action 78
# Random action 808
# PPO action 772
# Random action 70
# PPO action 161
# Random action 183
# PPO action 59
# Random action 730
# PPO action 329
# Random action 2
# PPO action 366
# score player 0 27 and player 1 24
# winner 1
# Episode 59 winner 1
# Playing episode 60/100
# Random action 1701
# PPO action 132
# Random action 173
# PPO action 1100
# Random action 1516
# PPO action 729
# Random action 1483
# PPO action 910
# Random action 125
# PPO action 481
# Random action 502
# PPO action 126
# Random action 1
# PPO action 1326
# Random action 308
# PPO action 34
# Random action 638
# PPO action 300
# Random action 1136
# score player 0 21 and player 1 22
# winner 0
# Episode 60 winner 0
# Random action 1743
# PPO action 382
# Random action 929
# PPO action 13
# Random action 860
# PPO action 1600
# Random action 125
# PPO action 233
# Random action 28
# PPO action 1482
# Random action 296
# PPO action 650
# Random action 548
# PPO action 290
# Random action 155
# PPO action 84
# Random action 749
# Random action 478
# score player 0 24 and player 1 25
# winner 0
# Episode 61 winner 0
# Random action 1719
# PPO action 1170
# Random action 197
# PPO action 128
# Random action 547
# PPO action 8
# Random action 1625
# PPO action 762
# Random action 556
# PPO action 93
# Random action 310
# PPO action 271
# Random action 111
# PPO action 1525
# Random action 674
# PPO action 1060
# Random action 972
# Random action 32
# score player 0 26 and player 1 24
# winner 1
# Episode 62 winner 1
# Random action 1697
# PPO action 1477
# Random action 1182
# PPO action 1490
# Random action 299
# PPO action 292
# Random action 132
# PPO action 846
# Random action 359
# PPO action 425
# Random action 30
# PPO action 104
# Random action 664
# PPO action 235
# Random action 78
# PPO action 10
# Random action 833
# PPO action 882
# PPO action 838
# score player 0 27 and player 1 21
# winner 1
# Episode 63 winner 1
# Random action 1744
# PPO action 1493
# Random action 78
# PPO action 1071
# Random action 1115
# PPO action 68
# Random action 367
# PPO action 254
# Random action 179
# PPO action 670
# Random action 741
# PPO action 1375
# Random action 1
# PPO action 520
# Random action 949
# PPO action 57
# Random action 66
# PPO action 219
# Random action 817
# Random action 344
# score player 0 24 and player 1 21
# winner 1
# Episode 64 winner 1
# Random action 1680
# PPO action 375
# Random action 1229
# PPO action 33
# Random action 833
# PPO action 67
# Random action 1486
# PPO action 822
# Random action 174
# PPO action 1349
# Random action 40
# PPO action 212
# Random action 241
# PPO action 320
# Random action 73
# PPO action 671
# Random action 359
# score player 0 25 and player 1 27
# winner 0
# Episode 65 winner 0
# Random action 1652
# PPO action 222
# Random action 98
# PPO action 244
# Random action 1284
# PPO action 89
# Random action 1611
# PPO action 416
# Random action 1424
# PPO action 1511
# Random action 59
# PPO action 840
# Random action 555
# PPO action 647
# Random action 339
# PPO action 46
# Random action 200
# PPO action 16
# Random action 460
# Random action 1132
# score player 0 16 and player 1 28
# winner 0
# Episode 66 winner 0
# Random action 1718
# PPO action 942
# Random action 1538
# PPO action 232
# Random action 214
# PPO action 673
# Random action 565
# PPO action 1293
# Random action 123
# PPO action 13
# Random action 4
# PPO action 121
# Random action 1487
# PPO action 436
# Random action 356
# PPO action 821
# Random action 250
# PPO action 254
# score player 0 25 and player 1 23
# winner 1
# Episode 67 winner 1
# Random action 1731
# PPO action 773
# Random action 1462
# PPO action 400
# Random action 56
# PPO action 972
# Random action 574
# PPO action 232
# Random action 354
# PPO action 1408
# Random action 194
# PPO action 844
# Random action 333
# PPO action 93
# Random action 102
# PPO action 270
# PPO action 6
# PPO action 589
# score player 0 30 and player 1 19
# winner 1
# Episode 68 winner 1
# Random action 1695
# PPO action 1044
# Random action 1425
# PPO action 0
# Random action 215
# PPO action 580
# Random action 379
# PPO action 130
# Random action 1618
# PPO action 86
# Random action 107
# PPO action 248
# Random action 6
# PPO action 1128
# Random action 256
# PPO action 532
# Random action 931
# PPO action 791
# Random action 44
# score player 0 24 and player 1 24
# winner -1
# Episode 69 winner -1
# Playing episode 70/100
# Random action 1708
# PPO action 45
# Random action 274
# PPO action 878
# Random action 1460
# PPO action 442
# Random action 359
# PPO action 617
# Random action 1491
# PPO action 114
# Random action 124
# PPO action 292
# Random action 24
# PPO action 1056
# Random action 651
# PPO action 217
# Random action 135
# PPO action 1062
# score player 0 25 and player 1 23
# winner 1
# Episode 70 winner 1
# Random action 1670
# PPO action 1214
# Random action 240
# PPO action 1487
# Random action 1323
# PPO action 508
# Random action 122
# PPO action 596
# Random action 200
# PPO action 63
# Random action 1228
# PPO action 172
# Random action 565
# PPO action 80
# Random action 826
# PPO action 291
# Random action 46
# score player 0 25 and player 1 25
# winner -1
# Episode 71 winner -1
# Random action 1733
# PPO action 155
# Random action 836
# PPO action 1173
# Random action 479
# PPO action 329
# Random action 127
# PPO action 899
# Random action 1037
# PPO action 1344
# Random action 12
# PPO action 791
# Random action 652
# PPO action 30
# Random action 173
# PPO action 108
# Random action 331
# PPO action 741
# Random action 113
# score player 0 28 and player 1 21
# winner 1
# Episode 72 winner 1
# Random action 1653
# PPO action 363
# Random action 443
# PPO action 872
# Random action 48
# PPO action 832
# Random action 1001
# PPO action 52
# Random action 271
# PPO action 131
# Random action 736
# PPO action 576
# Random action 746
# PPO action 345
# Random action 114
# PPO action 300
# Random action 157
# PPO action 125
# PPO action 998
# score player 0 28 and player 1 24
# winner 1
# Episode 73 winner 1
# Random action 1652
# PPO action 636
# Random action 674
# PPO action 888
# Random action 744
# PPO action 1122
# Random action 477
# PPO action 134
# Random action 1130
# PPO action 385
# Random action 1054
# PPO action 269
# Random action 25
# PPO action 34
# Random action 489
# PPO action 110
# Random action 145
# PPO action 749
# Random action 90
# PPO action 998
# Random action 271
# score player 0 24 and player 1 20
# winner 1
# Episode 74 winner 1
# Random action 1658
# PPO action 460
# Random action 1308
# PPO action 1463
# Random action 16
# PPO action 63
# Random action 104
# PPO action 589
# Random action 889
# PPO action 305
# Random action 722
# PPO action 122
# Random action 172
# PPO action 168
# Random action 343
# PPO action 6
# Random action 357
# PPO action 785
# Random action 833
# PPO action 976
# Random action 77
# score player 0 23 and player 1 23
# winner -1
# Episode 75 winner -1
# Random action 1700
# PPO action 1500
# Random action 876
# PPO action 285
# Random action 1490
# PPO action 540
# Random action 300
# PPO action 142
# Random action 643
# PPO action 742
# Random action 472
# PPO action 45
# Random action 53
# PPO action 125
# Random action 834
# PPO action 748
# Random action 104
# Random action 154
# score player 0 23 and player 1 27
# winner 0
# Episode 76 winner 0
# Random action 1675
# PPO action 819
# Random action 134
# PPO action 895
# Random action 715
# PPO action 446
# Random action 1326
# PPO action 318
# Random action 351
# PPO action 663
# Random action 538
# PPO action 110
# Random action 937
# PPO action 56
# Random action 117
# PPO action 172
# Random action 11
# Random action 806
# score player 0 23 and player 1 28
# winner 0
# Episode 77 winner 0
# Random action 1657
# PPO action 754
# Random action 474
# PPO action 1184
# Random action 49
# PPO action 1312
# Random action 868
# PPO action 239
# Random action 563
# PPO action 60
# Random action 137
# PPO action 87
# Random action 341
# PPO action 1483
# Random action 88
# PPO action 314
# Random action 749
# PPO action 727
# Random action 305
# PPO action 397
# PPO action 840
# score player 0 31 and player 1 13
# winner 1
# Episode 78 winner 1
# Random action 1751
# PPO action 1074
# Random action 1117
# PPO action 1492
# Random action 292
# PPO action 337
# Random action 1563
# PPO action 17
# Random action 186
# PPO action 572
# Random action 121
# PPO action 209
# Random action 47
# PPO action 941
# Random action 441
# PPO action 114
# Random action 764
# PPO action 746
# score player 0 26 and player 1 22
# winner 1
# Episode 79 winner 1
# Playing episode 80/100
# Random action 1702
# PPO action 1622
# Random action 1424
# PPO action 1365
# Random action 420
# PPO action 732
# Random action 327
# PPO action 312
# Random action 139
# PPO action 744
# Random action 89
# PPO action 393
# Random action 21
# PPO action 80
# Random action 888
# PPO action 357
# Random action 561
# PPO action 56
# Random action 792
# PPO action 143
# score player 0 23 and player 1 24
# winner 0
# Episode 80 winner 0
# Random action 1735
# PPO action 1270
# Random action 1182
# PPO action 1117
# Random action 601
# PPO action 655
# Random action 895
# PPO action 295
# Random action 55
# PPO action 545
# Random action 357
# PPO action 57
# Random action 348
# PPO action 973
# Random action 74
# PPO action 142
# Random action 161
# PPO action 100
# Random action 791
# Random action 846
# score player 0 19 and player 1 24
# winner 0
# Episode 81 winner 0
# Random action 1666
# PPO action 546
# Random action 334
# PPO action 89
# Random action 701
# PPO action 789
# Random action 1216
# PPO action 9
# Random action 493
# PPO action 587
# Random action 36
# PPO action 256
# Random action 124
# PPO action 218
# Random action 745
# PPO action 1067
# Random action 214
# PPO action 362
# Random action 1056
# score player 0 23 and player 1 28
# winner 0
# Episode 82 winner 0
# Random action 1695
# PPO action 1331
# Random action 1234
# PPO action 405
# Random action 1340
# PPO action 193
# Random action 80
# PPO action 1610
# Random action 1135
# PPO action 35
# Random action 1050
# PPO action 1036
# Random action 293
# PPO action 247
# Random action 589
# PPO action 96
# Random action 46
# Random action 172
# score player 0 20 and player 1 24
# winner 0
# Episode 83 winner 0
# Random action 1703
# PPO action 280
# Random action 1475
# PPO action 990
# Random action 301
# PPO action 159
# Random action 187
# PPO action 41
# Random action 1031
# PPO action 1519
# Random action 367
# PPO action 730
# Random action 15
# PPO action 746
# Random action 749
# PPO action 108
# Random action 125
# PPO action 504
# Random action 380
# PPO action 840
# Random action 653
# score player 0 23 and player 1 19
# winner 1
# Episode 84 winner 1
# Random action 1659
# PPO action 453
# Random action 1392
# PPO action 1140
# Random action 561
# PPO action 925
# Random action 1121
# PPO action 14
# Random action 744
# PPO action 187
# Random action 69
# PPO action 285
# Random action 227
# PPO action 121
# Random action 42
# PPO action 1428
# Random action 507
# PPO action 87
# Random action 304
# score player 0 23 and player 1 25
# winner 0
# Episode 85 winner 0
# Random action 1740
# PPO action 1353
# Random action 637
# PPO action 326
# Random action 849
# PPO action 819
# Random action 1011
# PPO action 17
# Random action 253
# PPO action 65
# Random action 59
# PPO action 1093
# Random action 76
# PPO action 237
# Random action 416
# PPO action 546
# Random action 1346
# Random action 201
# score player 0 22 and player 1 26
# winner 0
# Episode 86 winner 0
# Random action 1648
# PPO action 344
# Random action 1580
# PPO action 510
# Random action 1122
# PPO action 824
# Random action 1383
# PPO action 118
# Random action 891
# PPO action 225
# Random action 370
# PPO action 35
# Random action 237
# PPO action 644
# Random action 34
# Random action 111
# Random action 301
# Random action 600
# score player 0 17 and player 1 32
# winner 0
# Episode 87 winner 0
# Random action 1713
# PPO action 435
# Random action 517
# PPO action 342
# Random action 1380
# PPO action 195
# Random action 561
# PPO action 1068
# Random action 268
# PPO action 703
# Random action 1
# PPO action 9
# Random action 226
# PPO action 87
# Random action 105
# PPO action 839
# Random action 764
# score player 0 27 and player 1 28
# winner 0
# Episode 88 winner 0
# Random action 1678
# PPO action 1119
# Random action 324
# PPO action 839
# Random action 1339
# PPO action 527
# Random action 97
# PPO action 267
# Random action 1490
# PPO action 669
# Random action 57
# PPO action 22
# Random action 836
# PPO action 138
# Random action 173
# PPO action 77
# Random action 675
# PPO action 972
# score player 0 25 and player 1 24
# winner 1
# Episode 89 winner 1
# Playing episode 90/100
# Random action 1670
# PPO action 256
# Random action 872
# PPO action 732
# Random action 727
# PPO action 456
# Random action 932
# PPO action 88
# Random action 439
# PPO action 885
# Random action 130
# PPO action 63
# Random action 111
# PPO action 137
# Random action 48
# PPO action 976
# Random action 299
# score player 0 27 and player 1 27
# winner -1
# Episode 90 winner -1
# Random action 1731
# PPO action 188
# Random action 508
# PPO action 98
# Random action 100
# PPO action 781
# Random action 1296
# PPO action 395
# Random action 552
# PPO action 558
# Random action 20
# PPO action 254
# Random action 239
# PPO action 3
# Random action 805
# PPO action 1468
# Random action 274
# PPO action 1026
# score player 0 30 and player 1 23
# winner 1
# Episode 91 winner 1
# Random action 1633
# PPO action 888
# Random action 1095
# PPO action 790
# Random action 1155
# PPO action 1562
# Random action 713
# PPO action 227
# Random action 100
# PPO action 364
# Random action 333
# PPO action 108
# Random action 805
# PPO action 17
# Random action 48
# PPO action 311
# Random action 157
# score player 0 26 and player 1 26
# winner -1
# Episode 92 winner -1
# Random action 1672
# PPO action 1575
# Random action 504
# PPO action 1373
# Random action 722
# PPO action 159
# Random action 15
# PPO action 474
# Random action 751
# PPO action 744
# Random action 82
# PPO action 118
# Random action 139
# PPO action 333
# Random action 349
# PPO action 56
# Random action 1030
# PPO action 75
# PPO action 630
# score player 0 28 and player 1 22
# winner 1
# Episode 93 winner 1
# Random action 1718
# PPO action 730
# Random action 664
# PPO action 1510
# Random action 166
# PPO action 1409
# Random action 1063
# PPO action 905
# Random action 293
# PPO action 513
# Random action 52
# PPO action 130
# Random action 1056
# PPO action 71
# Random action 80
# PPO action 55
# Random action 1430
# PPO action 18
# PPO action 246
# score player 0 25 and player 1 21
# winner 1
# Episode 94 winner 1
# Random action 1693
# PPO action 773
# Random action 1318
# PPO action 641
# Random action 1148
# PPO action 481
# Random action 202
# PPO action 216
# Random action 66
# PPO action 1483
# Random action 764
# PPO action 68
# Random action 269
# PPO action 7
# Random action 45
# PPO action 273
# Random action 387
# PPO action 59
# Random action 663
# score player 0 22 and player 1 27
# winner 0
# Episode 95 winner 0
# Random action 1672
# PPO action 1023
# Random action 842
# PPO action 1295
# Random action 1444
# PPO action 545
# Random action 1265
# PPO action 277
# Random action 140
# PPO action 204
# Random action 322
# PPO action 791
# Random action 562
# PPO action 78
# Random action 65
# PPO action 60
# Random action 35
# PPO action 555
# Random action 233
# score player 0 24 and player 1 23
# winner 1
# Episode 96 winner 1
# Random action 1655
# PPO action 22
# Random action 857
# PPO action 715
# Random action 618
# PPO action 346
# Random action 1162
# PPO action 866
# Random action 1602
# PPO action 81
# Random action 1029
# PPO action 193
# Random action 97
# PPO action 838
# Random action 134
# PPO action 1024
# Random action 12
# PPO action 352
# Random action 284
# score player 0 20 and player 1 24
# winner 0
# Episode 97 winner 0
# Random action 1707
# PPO action 972
# Random action 509
# PPO action 265
# Random action 881
# PPO action 681
# Random action 1285
# PPO action 127
# Random action 56
# PPO action 51
# Random action 287
# PPO action 544
# Random action 67
# PPO action 137
# Random action 227
# PPO action 793
# Random action 749
# Random action 664
# score player 0 23 and player 1 28
# winner 0
# Episode 98 winner 0
# Random action 1646
# PPO action 336
# Random action 502
# PPO action 53
# Random action 733
# PPO action 1327
# Random action 860
# PPO action 1115
# Random action 1384
# PPO action 67
# Random action 61
# PPO action 1204
# Random action 145
# PPO action 819
# Random action 348
# PPO action 742
# Random action 71
# PPO action 425
# Random action 811
# PPO action 138
# score player 0 23 and player 1 18
# winner 1
# Episode 99 winner 1
#
# ===== Evaluation Results =====
# Episodes played: 100
# PPO Wins: 53 (53.00%)
# Random Wins: 40 (40.00%)
# Draws: 7 (7.00%)
# Average PPO Reward: -13.71
# Average Random Reward: -13.01
